# %% [markdown]
# # **Explore overfitting and underfitting**
# In both of the previous notebooks—classifying movie reviews, and predicting housing prices—we saw that the accuracy of our model on the validation data would peak after training for a number of epochs, and would then start decreasing.
#
# In other words, our model would overfit to the training data. Learning how to deal with overfitting is important. Although it's often possible to achieve high accuracy on the training set, what we really want is to develop models that generalize well to a testing data (or data they haven't seen before).
#
# The opposite of overfitting is underfitting. Underfitting occurs when there is still room for improvement on the test data. This can happen for a number of reasons: If the model is not powerful enough, is over-regularized, or has simply not been trained long enough. This means the network has not learned the relevant patterns in the training data.
#
# If you train for too long though, the model will start to overfit and learn patterns from the training data that don't generalize to the test data. We need to strike a balance. Understanding how to train for an appropriate number of epochs as we'll explore below is a useful skill.
#
# To prevent overfitting, the best solution is to use more training data. A model trained on more data will naturally generalize better. When that is no longer possible, the next best solution is to use techniques like regularization. These place constraints on the quantity and type of information your model can store. If a network can only afford to memorize a small number of patterns, the optimization process will force it to focus on the most prominent patterns, which have a better chance of generalizing well.
#
# In this notebook, we'll explore two common regularization techniques—weight regularization and dropout—and use them to improve our IMDB movie review classification notebook.

# %%
# %matplotlib inline
import keras
import tensorflow

import numpy as np
import matplotlib.pyplot as plt

print(keras.__version__)
# Out:
# 2.8.0

# %% [markdown]
# ## **Download the IMDB dataset**
# Rather than using an embedding as in the previous notebook, here we will multi-hot encode the sentences. This model will quickly overfit to the training set. It will be used to demonstrate when overfitting occurs, and how to fight it.
#
# Multi-hot-encoding our lists means turning them into vectors of 0s and 1s. Concretely, this would mean for instance turning the sequence [3, 5] into a 10,000-dimensional vector that would be all-zeros except for indices 3 and 5, which would be ones.

# %%
NUM_WORDS = 10000

(train_data, train_labels), (test_data, test_labels) = tensorflow.keras.datasets.imdb.load_data(num_words=NUM_WORDS)

def multi_hot_sequences(sequences, dimension):
    # Create an all-zero matrix of shape (len(sequences), dimension)
    results = np.zeros((len(sequences), dimension))
    for i, word_indices in enumerate(sequences):
        results[i, word_indices] = 1.0  # set specific indices of results[i] to 1s
    return results


train_data = multi_hot_sequences(train_data, dimension=NUM_WORDS)
test_data = multi_hot_sequences(test_data, dimension=NUM_WORDS)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 0s 0us/step
# 17473536/17464789 [==============================] - 0s 0us/step

# %% [markdown]
# Let's look at one of the resulting multi-hot vectors. The word indices are sorted by frequency, so it is expected that there are more 1-values near index zero, as we can see in this plot:

# %%
plt.plot(train_data[0])

# %% [markdown]
# # **Demonstrate overfitting**
# The simplest way to prevent overfitting is to reduce the size of the model, i.e. the number of learnable parameters in the model (which is determined by the number of layers and the number of units per layer). In deep learning, the number of learnable parameters in a model is often referred to as the model's "capacity". Intuitively, a model with more parameters will have more "memorization capacity" and therefore will be able to easily learn a perfect dictionary-like mapping between training samples and their targets, a mapping without any generalization power, but this would be useless when making predictions on previously unseen data.
#
# Always keep this in mind: deep learning models tend to be good at fitting to the training data, but the real challenge is generalization, not fitting.
#
# On the other hand, if the network has limited memorization resources, it will not be able to learn the mapping as easily. To minimize its loss, it will have to learn compressed representations that have more predictive power. At the same time, if you make your model too small, it will have difficulty fitting to the training data. There is a balance between "too much capacity" and "not enough capacity".
#
# Unfortunately, there is no magical formula to determine the right size or architecture of your model (in terms of the number of layers, or what the right size for each layer). You will have to experiment using a series of different architectures.
#
# To find an appropriate model size, it's best to start with relatively few layers and parameters, then begin increasing the size of the layers or adding new layers until you see diminishing returns on the validation loss. Let's try this on our movie review classification network.
#
# We'll create a simple model using only Dense layers as a baseline, then create smaller and larger versions, and compare them.
#
# ##**Create a baseline model**

# %%
baseline_model = keras.Sequential([
    # `input_shape` is only required here so that `.summary` works. 
    keras.layers.Dense(16, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

baseline_model.compile(optimizer='adam',
                       loss='binary_crossentropy',
                       metrics=['accuracy', 'binary_crossentropy'])

baseline_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                160016
#
#  dense_1 (Dense)             (None, 16)                272
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
baseline_history = baseline_model.fit(train_data,
                                      train_labels,
                                      epochs=20,
                                      batch_size=512,
                                      validation_data=(test_data, test_labels),
                                      verbose=2)
# Out:
# Epoch 1/20
# 49/49 - 6s - loss: 0.4758 - accuracy: 0.8013 - binary_crossentropy: 0.4758 - val_loss: 0.3253 - val_accuracy: 0.8791 - val_binary_crossentropy: 0.3253 - 6s/epoch - 123ms/step
# Epoch 2/20
# 49/49 - 2s - loss: 0.2375 - accuracy: 0.9133 - binary_crossentropy: 0.2375 - val_loss: 0.2823 - val_accuracy: 0.8885 - val_binary_crossentropy: 0.2823 - 2s/epoch - 45ms/step
# Epoch 3/20
# 49/49 - 2s - loss: 0.1740 - accuracy: 0.9380 - binary_crossentropy: 0.1740 - val_loss: 0.2996 - val_accuracy: 0.8824 - val_binary_crossentropy: 0.2996 - 2s/epoch - 45ms/step
# Epoch 4/20
# 49/49 - 2s - loss: 0.1380 - accuracy: 0.9536 - binary_crossentropy: 0.1380 - val_loss: 0.3248 - val_accuracy: 0.8773 - val_binary_crossentropy: 0.3248 - 2s/epoch - 31ms/step
# Epoch 5/20
# 49/49 - 2s - loss: 0.1117 - accuracy: 0.9634 - binary_crossentropy: 0.1117 - val_loss: 0.3565 - val_accuracy: 0.8726 - val_binary_crossentropy: 0.3565 - 2s/epoch - 41ms/step
# Epoch 6/20
# 49/49 - 2s - loss: 0.0929 - accuracy: 0.9705 - binary_crossentropy: 0.0929 - val_loss: 0.3985 - val_accuracy: 0.8674 - val_binary_crossentropy: 0.3985 - 2s/epoch - 36ms/step
# Epoch 7/20
# 49/49 - 1s - loss: 0.0763 - accuracy: 0.9768 - binary_crossentropy: 0.0763 - val_loss: 0.4424 - val_accuracy: 0.8638 - val_binary_crossentropy: 0.4424 - 1s/epoch - 30ms/step
# Epoch 8/20
# 49/49 - 2s - loss: 0.0631 - accuracy: 0.9834 - binary_crossentropy: 0.0631 - val_loss: 0.4849 - val_accuracy: 0.8612 - val_binary_crossentropy: 0.4849 - 2s/epoch - 31ms/step
# Epoch 9/20
# 49/49 - 1s - loss: 0.0507 - accuracy: 0.9874 - binary_crossentropy: 0.0507 - val_loss: 0.5363 - val_accuracy: 0.8585 - val_binary_crossentropy: 0.5363 - 1s/epoch - 30ms/step
# Epoch 10/20
# 49/49 - 1s - loss: 0.0408 - accuracy: 0.9916 - binary_crossentropy: 0.0408 - val_loss: 0.5891 - val_accuracy: 0.8550 - val_binary_crossentropy: 0.5891 - 1s/epoch - 30ms/step
# Epoch 11/20
# 49/49 - 2s - loss: 0.0316 - accuracy: 0.9941 - binary_crossentropy: 0.0316 - val_loss: 0.6296 - val_accuracy: 0.8542 - val_binary_crossentropy: 0.6296 - 2s/epoch - 31ms/step
# Epoch 12/20
# 49/49 - 2s - loss: 0.0241 - accuracy: 0.9966 - binary_crossentropy: 0.0241 - val_loss: 0.6985 - val_accuracy: 0.8513 - val_binary_crossentropy: 0.6985 - 2s/epoch - 31ms/step
# Epoch 13/20
# 49/49 - 1s - loss: 0.0174 - accuracy: 0.9980 - binary_crossentropy: 0.0174 - val_loss: 0.7339 - val_accuracy: 0.8513 - val_binary_crossentropy: 0.7339 - 1s/epoch - 30ms/step
# Epoch 14/20
# 49/49 - 1s - loss: 0.0127 - accuracy: 0.9992 - binary_crossentropy: 0.0127 - val_loss: 0.7796 - val_accuracy: 0.8504 - val_binary_crossentropy: 0.7796 - 1s/epoch - 30ms/step
# Epoch 15/20
# 49/49 - 1s - loss: 0.0093 - accuracy: 0.9995 - binary_crossentropy: 0.0093 - val_loss: 0.8224 - val_accuracy: 0.8498 - val_binary_crossentropy: 0.8224 - 1s/epoch - 30ms/step
# Epoch 16/20
# 49/49 - 1s - loss: 0.0068 - accuracy: 0.9998 - binary_crossentropy: 0.0068 - val_loss: 0.8607 - val_accuracy: 0.8496 - val_binary_crossentropy: 0.8607 - 1s/epoch - 30ms/step
# Epoch 17/20
# 49/49 - 1s - loss: 0.0052 - accuracy: 0.9999 - binary_crossentropy: 0.0052 - val_loss: 0.8931 - val_accuracy: 0.8489 - val_binary_crossentropy: 0.8931 - 1s/epoch - 30ms/step
# Epoch 18/20
# 49/49 - 2s - loss: 0.0041 - accuracy: 0.9999 - binary_crossentropy: 0.0041 - val_loss: 0.9162 - val_accuracy: 0.8501 - val_binary_crossentropy: 0.9162 - 2s/epoch - 31ms/step
# Epoch 19/20
# 49/49 - 1s - loss: 0.0033 - accuracy: 0.9999 - binary_crossentropy: 0.0033 - val_loss: 0.9450 - val_accuracy: 0.8492 - val_binary_crossentropy: 0.9450 - 1s/epoch - 30ms/step
# Epoch 20/20
# 49/49 - 1s - loss: 0.0028 - accuracy: 1.0000 - binary_crossentropy: 0.0028 - val_loss: 0.9718 - val_accuracy: 0.8491 - val_binary_crossentropy: 0.9718 - 1s/epoch - 30ms/step

# %% [markdown]
# ##Create a smaller model
# Let's create a model with less hidden units to compare against the baseline model that we just created:

# %%
smaller_model = keras.Sequential([
    keras.layers.Dense(4, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(4, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

smaller_model.compile(optimizer='adam',
                loss='binary_crossentropy',
                metrics=['accuracy', 'binary_crossentropy'])

smaller_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 4)                 40004
#
#  dense_4 (Dense)             (None, 4)                 20
#
#  dense_5 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 40,029
# Trainable params: 40,029
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# And train the model using the same data:

# %%
smaller_history = smaller_model.fit(train_data,
                                    train_labels,
                                    epochs=20,
                                    batch_size=512,
                                    validation_data=(test_data, test_labels),
                                    verbose=2)
# Out:
# Epoch 1/20
# 49/49 - 3s - loss: 0.6490 - accuracy: 0.7082 - binary_crossentropy: 0.6490 - val_loss: 0.5873 - val_accuracy: 0.7972 - val_binary_crossentropy: 0.5873 - 3s/epoch - 53ms/step
# Epoch 2/20
# 49/49 - 1s - loss: 0.5071 - accuracy: 0.8523 - binary_crossentropy: 0.5071 - val_loss: 0.4603 - val_accuracy: 0.8572 - val_binary_crossentropy: 0.4603 - 1s/epoch - 30ms/step
# Epoch 3/20
# 49/49 - 2s - loss: 0.3838 - accuracy: 0.8880 - binary_crossentropy: 0.3838 - val_loss: 0.3747 - val_accuracy: 0.8722 - val_binary_crossentropy: 0.3747 - 2s/epoch - 31ms/step
# Epoch 4/20
# 49/49 - 2s - loss: 0.3038 - accuracy: 0.9054 - binary_crossentropy: 0.3038 - val_loss: 0.3272 - val_accuracy: 0.8810 - val_binary_crossentropy: 0.3272 - 2s/epoch - 35ms/step
# Epoch 5/20
# 49/49 - 1s - loss: 0.2547 - accuracy: 0.9184 - binary_crossentropy: 0.2547 - val_loss: 0.3025 - val_accuracy: 0.8853 - val_binary_crossentropy: 0.3025 - 1s/epoch - 30ms/step
# Epoch 6/20
# 49/49 - 1s - loss: 0.2222 - accuracy: 0.9275 - binary_crossentropy: 0.2222 - val_loss: 0.2900 - val_accuracy: 0.8883 - val_binary_crossentropy: 0.2900 - 1s/epoch - 30ms/step
# Epoch 7/20
# 49/49 - 1s - loss: 0.1979 - accuracy: 0.9347 - binary_crossentropy: 0.1979 - val_loss: 0.2858 - val_accuracy: 0.8872 - val_binary_crossentropy: 0.2858 - 1s/epoch - 30ms/step
# Epoch 8/20
# 49/49 - 1s - loss: 0.1792 - accuracy: 0.9417 - binary_crossentropy: 0.1792 - val_loss: 0.2834 - val_accuracy: 0.8874 - val_binary_crossentropy: 0.2834 - 1s/epoch - 31ms/step
# Epoch 9/20
# 49/49 - 1s - loss: 0.1642 - accuracy: 0.9465 - binary_crossentropy: 0.1642 - val_loss: 0.2848 - val_accuracy: 0.8872 - val_binary_crossentropy: 0.2848 - 1s/epoch - 30ms/step
# Epoch 10/20
# 49/49 - 1s - loss: 0.1513 - accuracy: 0.9517 - binary_crossentropy: 0.1513 - val_loss: 0.2912 - val_accuracy: 0.8837 - val_binary_crossentropy: 0.2912 - 1s/epoch - 30ms/step
# Epoch 11/20
# 49/49 - 1s - loss: 0.1400 - accuracy: 0.9559 - binary_crossentropy: 0.1400 - val_loss: 0.2951 - val_accuracy: 0.8838 - val_binary_crossentropy: 0.2951 - 1s/epoch - 30ms/step
# Epoch 12/20
# 49/49 - 1s - loss: 0.1299 - accuracy: 0.9594 - binary_crossentropy: 0.1299 - val_loss: 0.3040 - val_accuracy: 0.8810 - val_binary_crossentropy: 0.3040 - 1s/epoch - 30ms/step
# Epoch 13/20
# 49/49 - 1s - loss: 0.1212 - accuracy: 0.9626 - binary_crossentropy: 0.1212 - val_loss: 0.3157 - val_accuracy: 0.8788 - val_binary_crossentropy: 0.3157 - 1s/epoch - 30ms/step
# Epoch 14/20
# 49/49 - 1s - loss: 0.1138 - accuracy: 0.9652 - binary_crossentropy: 0.1138 - val_loss: 0.3187 - val_accuracy: 0.8788 - val_binary_crossentropy: 0.3187 - 1s/epoch - 30ms/step
# Epoch 15/20
# 49/49 - 2s - loss: 0.1063 - accuracy: 0.9693 - binary_crossentropy: 0.1063 - val_loss: 0.3289 - val_accuracy: 0.8778 - val_binary_crossentropy: 0.3289 - 2s/epoch - 35ms/step
# Epoch 16/20
# 49/49 - 2s - loss: 0.0994 - accuracy: 0.9719 - binary_crossentropy: 0.0994 - val_loss: 0.3410 - val_accuracy: 0.8748 - val_binary_crossentropy: 0.3410 - 2s/epoch - 39ms/step
# Epoch 17/20
# 49/49 - 1s - loss: 0.0936 - accuracy: 0.9740 - binary_crossentropy: 0.0936 - val_loss: 0.3510 - val_accuracy: 0.8747 - val_binary_crossentropy: 0.3510 - 1s/epoch - 30ms/step
# Epoch 18/20
# 49/49 - 2s - loss: 0.0879 - accuracy: 0.9759 - binary_crossentropy: 0.0879 - val_loss: 0.3645 - val_accuracy: 0.8714 - val_binary_crossentropy: 0.3645 - 2s/epoch - 31ms/step
# Epoch 19/20
# 49/49 - 1s - loss: 0.0826 - accuracy: 0.9782 - binary_crossentropy: 0.0826 - val_loss: 0.3755 - val_accuracy: 0.8703 - val_binary_crossentropy: 0.3755 - 1s/epoch - 31ms/step
# Epoch 20/20
# 49/49 - 2s - loss: 0.0775 - accuracy: 0.9800 - binary_crossentropy: 0.0775 - val_loss: 0.3894 - val_accuracy: 0.8682 - val_binary_crossentropy: 0.3894 - 2s/epoch - 40ms/step

# %% [markdown]
# ##Create a bigger model
# As an exercise, you can create an even larger model, and see how quickly it begins overfitting. Next, let's add to this benchmark a network that has much more capacity, far more than the problem would warrant:

# %%
bigger_model = keras.models.Sequential([
    keras.layers.Dense(512, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(512, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

bigger_model.compile(optimizer='adam',
                     loss='binary_crossentropy',
                     metrics=['accuracy','binary_crossentropy'])

bigger_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 512)               5120512
#
#  dense_7 (Dense)             (None, 512)               262656
#
#  dense_8 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 5,383,681
# Trainable params: 5,383,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
bigger_history = bigger_model.fit(train_data, train_labels,
                                  epochs=20,
                                  batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# Epoch 1/20
# 49/49 - 15s - loss: 0.3409 - accuracy: 0.8529 - binary_crossentropy: 0.3409 - val_loss: 0.2922 - val_accuracy: 0.8800 - val_binary_crossentropy: 0.2922 - 15s/epoch - 303ms/step
# Epoch 2/20
# 49/49 - 16s - loss: 0.1394 - accuracy: 0.9502 - binary_crossentropy: 0.1394 - val_loss: 0.3262 - val_accuracy: 0.8734 - val_binary_crossentropy: 0.3262 - 16s/epoch - 319ms/step
# Epoch 3/20
# 49/49 - 13s - loss: 0.0435 - accuracy: 0.9872 - binary_crossentropy: 0.0435 - val_loss: 0.4527 - val_accuracy: 0.8690 - val_binary_crossentropy: 0.4527 - 13s/epoch - 262ms/step
# Epoch 4/20
# 49/49 - 13s - loss: 0.0063 - accuracy: 0.9992 - binary_crossentropy: 0.0063 - val_loss: 0.5830 - val_accuracy: 0.8697 - val_binary_crossentropy: 0.5830 - 13s/epoch - 269ms/step
# Epoch 5/20
# 49/49 - 13s - loss: 7.1633e-04 - accuracy: 1.0000 - binary_crossentropy: 7.1633e-04 - val_loss: 0.6918 - val_accuracy: 0.8711 - val_binary_crossentropy: 0.6918 - 13s/epoch - 263ms/step
# Epoch 6/20
# 49/49 - 13s - loss: 2.0910e-04 - accuracy: 1.0000 - binary_crossentropy: 2.0910e-04 - val_loss: 0.7337 - val_accuracy: 0.8722 - val_binary_crossentropy: 0.7337 - 13s/epoch - 263ms/step
# Epoch 7/20
# 49/49 - 13s - loss: 1.2915e-04 - accuracy: 1.0000 - binary_crossentropy: 1.2915e-04 - val_loss: 0.7645 - val_accuracy: 0.8720 - val_binary_crossentropy: 0.7645 - 13s/epoch - 273ms/step
# Epoch 8/20
# 49/49 - 14s - loss: 9.2406e-05 - accuracy: 1.0000 - binary_crossentropy: 9.2406e-05 - val_loss: 0.7865 - val_accuracy: 0.8725 - val_binary_crossentropy: 0.7865 - 14s/epoch - 276ms/step
# Epoch 9/20
# 49/49 - 15s - loss: 7.0889e-05 - accuracy: 1.0000 - binary_crossentropy: 7.0889e-05 - val_loss: 0.8062 - val_accuracy: 0.8724 - val_binary_crossentropy: 0.8062 - 15s/epoch - 297ms/step
# Epoch 10/20
# 49/49 - 16s - loss: 5.6365e-05 - accuracy: 1.0000 - binary_crossentropy: 5.6365e-05 - val_loss: 0.8226 - val_accuracy: 0.8725 - val_binary_crossentropy: 0.8226 - 16s/epoch - 319ms/step
# Epoch 11/20
# 49/49 - 13s - loss: 4.6124e-05 - accuracy: 1.0000 - binary_crossentropy: 4.6124e-05 - val_loss: 0.8375 - val_accuracy: 0.8723 - val_binary_crossentropy: 0.8375 - 13s/epoch - 266ms/step
# Epoch 12/20
# 49/49 - 13s - loss: 3.8552e-05 - accuracy: 1.0000 - binary_crossentropy: 3.8552e-05 - val_loss: 0.8506 - val_accuracy: 0.8724 - val_binary_crossentropy: 0.8506 - 13s/epoch - 271ms/step
# Epoch 13/20
# 49/49 - 13s - loss: 3.2702e-05 - accuracy: 1.0000 - binary_crossentropy: 3.2702e-05 - val_loss: 0.8625 - val_accuracy: 0.8723 - val_binary_crossentropy: 0.8625 - 13s/epoch - 271ms/step
# Epoch 14/20
# 49/49 - 13s - loss: 2.8119e-05 - accuracy: 1.0000 - binary_crossentropy: 2.8119e-05 - val_loss: 0.8738 - val_accuracy: 0.8726 - val_binary_crossentropy: 0.8738 - 13s/epoch - 262ms/step
# Epoch 15/20
# 49/49 - 15s - loss: 2.4435e-05 - accuracy: 1.0000 - binary_crossentropy: 2.4435e-05 - val_loss: 0.8844 - val_accuracy: 0.8726 - val_binary_crossentropy: 0.8844 - 15s/epoch - 299ms/step
# Epoch 16/20
# 49/49 - 13s - loss: 2.1421e-05 - accuracy: 1.0000 - binary_crossentropy: 2.1421e-05 - val_loss: 0.8940 - val_accuracy: 0.8724 - val_binary_crossentropy: 0.8940 - 13s/epoch - 263ms/step
# Epoch 17/20
# 49/49 - 13s - loss: 1.8937e-05 - accuracy: 1.0000 - binary_crossentropy: 1.8937e-05 - val_loss: 0.9030 - val_accuracy: 0.8726 - val_binary_crossentropy: 0.9030 - 13s/epoch - 263ms/step
# Epoch 18/20
# 49/49 - 13s - loss: 1.6854e-05 - accuracy: 1.0000 - binary_crossentropy: 1.6854e-05 - val_loss: 0.9117 - val_accuracy: 0.8728 - val_binary_crossentropy: 0.9117 - 13s/epoch - 262ms/step
# Epoch 19/20
# 49/49 - 13s - loss: 1.5084e-05 - accuracy: 1.0000 - binary_crossentropy: 1.5084e-05 - val_loss: 0.9200 - val_accuracy: 0.8726 - val_binary_crossentropy: 0.9200 - 13s/epoch - 262ms/step
# Epoch 20/20
# 49/49 - 13s - loss: 1.3579e-05 - accuracy: 1.0000 - binary_crossentropy: 1.3579e-05 - val_loss: 0.9278 - val_accuracy: 0.8727 - val_binary_crossentropy: 0.9278 - 13s/epoch - 262ms/step

# %% [markdown]
# ##Plot the training and validation loss
# The solid lines show the training loss, and the dashed lines show the validation loss (remember: a lower validation loss indicates a better model). Here, the smaller network begins overfitting later than the baseline model (after 6 epochs rather than 4) and its performance degrades much more slowly once it starts overfitting.

# %%
def plot_history(histories, key='binary_crossentropy'):
  plt.figure(figsize=(16,10))
    
  for name, history in histories:
    val = plt.plot(history.epoch, history.history['val_'+key],
                   '--', label=name.title()+' Val')
    plt.plot(history.epoch, history.history[key], color=val[0].get_color(),
             label=name.title()+' Train')

  plt.xlabel('Epochs')
  plt.ylabel(key.replace('_',' ').title())
  plt.legend()

  plt.xlim([0,max(history.epoch)])


plot_history([('baseline', baseline_history),
              ('smaller', smaller_history),
              ('bigger', bigger_history)])

# %% [markdown]
# Notice that the larger network begins overfitting almost right away, after just one epoch, and overfits much more severely. The more capacity the network has, the quicker it will be able to model the training data (resulting in a low training loss), but the more susceptible it is to overfitting (resulting in a large difference between the training and validation loss).
#
# # **Strategies**
# ## Add weight regularization
# You may be familiar with Occam's Razor principle: given two explanations for something, the explanation most likely to be correct is the "simplest" one, the one that makes the least amount of assumptions. This also applies to the models learned by neural networks: given some training data and a network architecture, there are multiple sets of weights values (multiple models) that could explain the data, and simpler models are less likely to overfit than complex ones.
#
# A "simple model" in this context is a model where the distribution of parameter values has less entropy (or a model with fewer parameters altogether, as we saw in the section above). Thus a common way to mitigate overfitting is to put constraints on the complexity of a network by forcing its weights only to take small values, which makes the distribution of weight values more "regular". This is called "weight regularization", and it is done by adding to the loss function of the network a cost associated with having large weights. This cost comes in two flavors:
#
# * L1 regularization, where the cost added is proportional to the absolute value of the weights coefficients (i.e. to what is called the "L1 norm" of the weights).
#
# * L2 regularization, where the cost added is proportional to the square of the value of the weights coefficients (i.e. to what is called the "L2 norm" of the weights). L2 regularization is also called weight decay in the context of neural networks. Don't let the different name confuse you: weight decay is mathematically the exact same as L2 regularization.
#
# In Keras, weight regularization is added by passing weight regularizer instances to layers as keyword arguments. Let's add L2 weight regularization now.

# %%
l2_model = keras.models.Sequential([
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                       activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                       activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

l2_model.compile(optimizer='adam',
                 loss='binary_crossentropy',
                 metrics=['accuracy', 'binary_crossentropy'])

l2_model_history = l2_model.fit(train_data, train_labels,
                                epochs=20,
                                batch_size=512,
                                validation_data=(test_data, test_labels),
                                verbose=2)
# Out:
# Epoch 1/20
# 49/49 - 3s - loss: 0.5198 - accuracy: 0.8018 - binary_crossentropy: 0.4762 - val_loss: 0.3829 - val_accuracy: 0.8749 - val_binary_crossentropy: 0.3366 - 3s/epoch - 56ms/step
# Epoch 2/20
# 49/49 - 2s - loss: 0.3058 - accuracy: 0.9105 - binary_crossentropy: 0.2547 - val_loss: 0.3388 - val_accuracy: 0.8872 - val_binary_crossentropy: 0.2843 - 2s/epoch - 31ms/step
# Epoch 3/20
# 49/49 - 1s - loss: 0.2570 - accuracy: 0.9308 - binary_crossentropy: 0.2001 - val_loss: 0.3437 - val_accuracy: 0.8847 - val_binary_crossentropy: 0.2852 - 1s/epoch - 30ms/step
# Epoch 4/20
# 49/49 - 1s - loss: 0.2352 - accuracy: 0.9395 - binary_crossentropy: 0.1750 - val_loss: 0.3554 - val_accuracy: 0.8818 - val_binary_crossentropy: 0.2941 - 1s/epoch - 30ms/step
# Epoch 5/20
# 49/49 - 1s - loss: 0.2200 - accuracy: 0.9472 - binary_crossentropy: 0.1575 - val_loss: 0.3682 - val_accuracy: 0.8788 - val_binary_crossentropy: 0.3052 - 1s/epoch - 29ms/step
# Epoch 6/20
# 49/49 - 1s - loss: 0.2110 - accuracy: 0.9508 - binary_crossentropy: 0.1471 - val_loss: 0.3817 - val_accuracy: 0.8751 - val_binary_crossentropy: 0.3173 - 1s/epoch - 30ms/step
# Epoch 7/20
# 49/49 - 1s - loss: 0.2017 - accuracy: 0.9538 - binary_crossentropy: 0.1365 - val_loss: 0.3952 - val_accuracy: 0.8745 - val_binary_crossentropy: 0.3297 - 1s/epoch - 30ms/step
# Epoch 8/20
# 49/49 - 1s - loss: 0.1954 - accuracy: 0.9561 - binary_crossentropy: 0.1295 - val_loss: 0.4067 - val_accuracy: 0.8709 - val_binary_crossentropy: 0.3406 - 1s/epoch - 29ms/step
# Epoch 9/20
# 49/49 - 1s - loss: 0.1911 - accuracy: 0.9581 - binary_crossentropy: 0.1246 - val_loss: 0.4190 - val_accuracy: 0.8689 - val_binary_crossentropy: 0.3521 - 1s/epoch - 30ms/step
# Epoch 10/20
# 49/49 - 1s - loss: 0.1854 - accuracy: 0.9605 - binary_crossentropy: 0.1180 - val_loss: 0.4365 - val_accuracy: 0.8666 - val_binary_crossentropy: 0.3689 - 1s/epoch - 30ms/step
# Epoch 11/20
# 49/49 - 1s - loss: 0.1793 - accuracy: 0.9639 - binary_crossentropy: 0.1115 - val_loss: 0.4467 - val_accuracy: 0.8657 - val_binary_crossentropy: 0.3786 - 1s/epoch - 30ms/step
# Epoch 12/20
# 49/49 - 1s - loss: 0.1751 - accuracy: 0.9629 - binary_crossentropy: 0.1068 - val_loss: 0.4569 - val_accuracy: 0.8635 - val_binary_crossentropy: 0.3882 - 1s/epoch - 30ms/step
# Epoch 13/20
# 49/49 - 2s - loss: 0.1733 - accuracy: 0.9653 - binary_crossentropy: 0.1043 - val_loss: 0.4688 - val_accuracy: 0.8635 - val_binary_crossentropy: 0.3997 - 2s/epoch - 42ms/step
# Epoch 14/20
# 49/49 - 1s - loss: 0.1699 - accuracy: 0.9671 - binary_crossentropy: 0.1002 - val_loss: 0.4817 - val_accuracy: 0.8606 - val_binary_crossentropy: 0.4117 - 1s/epoch - 29ms/step
# Epoch 15/20
# 49/49 - 1s - loss: 0.1651 - accuracy: 0.9681 - binary_crossentropy: 0.0950 - val_loss: 0.4993 - val_accuracy: 0.8573 - val_binary_crossentropy: 0.4290 - 1s/epoch - 29ms/step
# Epoch 16/20
# 49/49 - 1s - loss: 0.1634 - accuracy: 0.9687 - binary_crossentropy: 0.0928 - val_loss: 0.4982 - val_accuracy: 0.8596 - val_binary_crossentropy: 0.4271 - 1s/epoch - 30ms/step
# Epoch 17/20
# 49/49 - 1s - loss: 0.1574 - accuracy: 0.9715 - binary_crossentropy: 0.0860 - val_loss: 0.5158 - val_accuracy: 0.8566 - val_binary_crossentropy: 0.4446 - 1s/epoch - 29ms/step
# Epoch 18/20
# 49/49 - 1s - loss: 0.1522 - accuracy: 0.9737 - binary_crossentropy: 0.0811 - val_loss: 0.5197 - val_accuracy: 0.8564 - val_binary_crossentropy: 0.4484 - 1s/epoch - 29ms/step
# Epoch 19/20
# 49/49 - 1s - loss: 0.1493 - accuracy: 0.9752 - binary_crossentropy: 0.0781 - val_loss: 0.5380 - val_accuracy: 0.8540 - val_binary_crossentropy: 0.4665 - 1s/epoch - 30ms/step
# Epoch 20/20
# 49/49 - 1s - loss: 0.1469 - accuracy: 0.9757 - binary_crossentropy: 0.0750 - val_loss: 0.5421 - val_accuracy: 0.8557 - val_binary_crossentropy: 0.4700 - 1s/epoch - 29ms/step

# %% [markdown]
# l2(0.001) means that every coefficient in the weight matrix of the layer will add  0.001 * weight_coefficient_value**2 to the total loss of the network. Note that because this penalty is only added at training time, the loss for this network will be much higher at training than at test time.
#
# Here's the impact of our L2 regularization penalty:

# %%
plot_history([('baseline', baseline_history),
              ('l2', l2_model_history)])

# %% [markdown]
# As you can see, the L2 regularized model has become much more resistant to overfitting than the baseline model, even though both models have the same number of parameters.
#
# ##Add dropout
# Dropout is one of the most effective and most commonly used regularization techniques for neural networks, developed by Hinton and his students at the University of Toronto. Dropout, applied to a layer, consists of randomly "dropping out" (i.e. set to zero) a number of output features of the layer during training. Let's say a given layer would normally have returned a vector [0.2, 0.5, 1.3, 0.8, 1.1] for a given input sample during training; after applying dropout, this vector will have a few zero entries distributed at random, e.g. [0, 0.5, 1.3, 0, 1.1]. The "dropout rate" is the fraction of the features that are being zeroed-out; it is usually set between 0.2 and 0.5. At test time, no units are dropped out, and instead the layer's output values are scaled down by a factor equal to the dropout rate, so as to balance for the fact that more units are active than at training time.
#
# In tf.keras you can introduce dropout in a network via the Dropout layer, which gets applied to the output of layer right before.
#
# Let's add two Dropout layers in our IMDB network to see how well they do at reducing overfitting:

# %%
dpt_model = keras.models.Sequential([
    keras.layers.Dense(16, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1, activation='sigmoid')
])

dpt_model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy','binary_crossentropy'])

dpt_model_history = dpt_model.fit(train_data, train_labels,
                                  epochs=20,
                                  batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# Epoch 1/20
# 49/49 - 6s - loss: 0.6063 - accuracy: 0.6639 - binary_crossentropy: 0.6063 - val_loss: 0.4515 - val_accuracy: 0.8631 - val_binary_crossentropy: 0.4515 - 6s/epoch - 118ms/step
# Epoch 2/20
# 49/49 - 2s - loss: 0.4323 - accuracy: 0.8230 - binary_crossentropy: 0.4323 - val_loss: 0.3280 - val_accuracy: 0.8829 - val_binary_crossentropy: 0.3280 - 2s/epoch - 35ms/step
# Epoch 3/20
# 49/49 - 2s - loss: 0.3449 - accuracy: 0.8774 - binary_crossentropy: 0.3449 - val_loss: 0.2862 - val_accuracy: 0.8892 - val_binary_crossentropy: 0.2862 - 2s/epoch - 32ms/step
# Epoch 4/20
# 49/49 - 2s - loss: 0.2780 - accuracy: 0.9015 - binary_crossentropy: 0.2780 - val_loss: 0.2773 - val_accuracy: 0.8892 - val_binary_crossentropy: 0.2773 - 2s/epoch - 32ms/step
# Epoch 5/20
# 49/49 - 2s - loss: 0.2416 - accuracy: 0.9197 - binary_crossentropy: 0.2416 - val_loss: 0.2775 - val_accuracy: 0.8881 - val_binary_crossentropy: 0.2775 - 2s/epoch - 33ms/step
# Epoch 6/20
# 49/49 - 2s - loss: 0.2111 - accuracy: 0.9298 - binary_crossentropy: 0.2111 - val_loss: 0.2868 - val_accuracy: 0.8864 - val_binary_crossentropy: 0.2868 - 2s/epoch - 32ms/step
# Epoch 7/20
# 49/49 - 2s - loss: 0.1817 - accuracy: 0.9396 - binary_crossentropy: 0.1817 - val_loss: 0.3070 - val_accuracy: 0.8846 - val_binary_crossentropy: 0.3070 - 2s/epoch - 32ms/step
# Epoch 8/20
# 49/49 - 2s - loss: 0.1630 - accuracy: 0.9474 - binary_crossentropy: 0.1630 - val_loss: 0.3242 - val_accuracy: 0.8819 - val_binary_crossentropy: 0.3242 - 2s/epoch - 32ms/step
# Epoch 9/20
# 49/49 - 2s - loss: 0.1469 - accuracy: 0.9532 - binary_crossentropy: 0.1469 - val_loss: 0.3303 - val_accuracy: 0.8797 - val_binary_crossentropy: 0.3303 - 2s/epoch - 32ms/step
# Epoch 10/20
# 49/49 - 2s - loss: 0.1320 - accuracy: 0.9570 - binary_crossentropy: 0.1320 - val_loss: 0.3630 - val_accuracy: 0.8791 - val_binary_crossentropy: 0.3630 - 2s/epoch - 33ms/step
# Epoch 11/20
# 49/49 - 2s - loss: 0.1194 - accuracy: 0.9611 - binary_crossentropy: 0.1194 - val_loss: 0.3742 - val_accuracy: 0.8786 - val_binary_crossentropy: 0.3742 - 2s/epoch - 33ms/step
# Epoch 12/20
# 49/49 - 2s - loss: 0.1101 - accuracy: 0.9639 - binary_crossentropy: 0.1101 - val_loss: 0.4082 - val_accuracy: 0.8773 - val_binary_crossentropy: 0.4082 - 2s/epoch - 32ms/step
# Epoch 13/20
# 49/49 - 2s - loss: 0.0992 - accuracy: 0.9671 - binary_crossentropy: 0.0992 - val_loss: 0.4493 - val_accuracy: 0.8764 - val_binary_crossentropy: 0.4493 - 2s/epoch - 32ms/step
# Epoch 14/20
# 49/49 - 2s - loss: 0.0927 - accuracy: 0.9694 - binary_crossentropy: 0.0927 - val_loss: 0.4393 - val_accuracy: 0.8773 - val_binary_crossentropy: 0.4393 - 2s/epoch - 32ms/step
# Epoch 15/20
# 49/49 - 2s - loss: 0.0857 - accuracy: 0.9709 - binary_crossentropy: 0.0857 - val_loss: 0.4873 - val_accuracy: 0.8741 - val_binary_crossentropy: 0.4873 - 2s/epoch - 31ms/step
# Epoch 16/20
# 49/49 - 2s - loss: 0.0818 - accuracy: 0.9716 - binary_crossentropy: 0.0818 - val_loss: 0.4836 - val_accuracy: 0.8752 - val_binary_crossentropy: 0.4836 - 2s/epoch - 32ms/step
# Epoch 17/20
# 49/49 - 2s - loss: 0.0773 - accuracy: 0.9738 - binary_crossentropy: 0.0773 - val_loss: 0.4870 - val_accuracy: 0.8757 - val_binary_crossentropy: 0.4870 - 2s/epoch - 32ms/step
# Epoch 18/20
# 49/49 - 2s - loss: 0.0758 - accuracy: 0.9736 - binary_crossentropy: 0.0758 - val_loss: 0.5251 - val_accuracy: 0.8752 - val_binary_crossentropy: 0.5251 - 2s/epoch - 34ms/step
# Epoch 19/20
# 49/49 - 2s - loss: 0.0712 - accuracy: 0.9760 - binary_crossentropy: 0.0712 - val_loss: 0.5344 - val_accuracy: 0.8740 - val_binary_crossentropy: 0.5344 - 2s/epoch - 32ms/step
# Epoch 20/20
# 49/49 - 2s - loss: 0.0679 - accuracy: 0.9761 - binary_crossentropy: 0.0679 - val_loss: 0.5677 - val_accuracy: 0.8745 - val_binary_crossentropy: 0.5677 - 2s/epoch - 32ms/step

# %%
plot_history([('baseline', baseline_history),
              ('dropout', dpt_model_history)])

# %% [markdown]
# Adding dropout is a clear improvement over the baseline model.
#
# To recap: here the most common ways to prevent overfitting in neural networks:
#
# * Get more training data.
# * Reduce the capacity of the network.
# * Add weight regularization.
# * Add dropout.
# And two important approaches not covered in this guide are data-augmentation and batch normalization.
